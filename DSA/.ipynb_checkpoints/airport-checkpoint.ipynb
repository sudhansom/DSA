# %%
airports = ["BGI", "CDG", "DEL", "DOH", "DSM", "EWR", "EYW", "HND", "ICN", "JFK", "LGA", "LHR", "ORD", "SAN", "SFO", "SIN", "TLV", "BUD"]
routes = [
    ["DSM", "ORD"],
    ["ORD", "BGI"],
    ["BGI", "LGA"],
    ["SIN", "CDG"],
    ["CDG", "SIN"],
    ["CDG", "BUD"],
    ["DEL", "DOH"],
    ["DEL", "CDG"],
    ["TLV", "DEL"],
    ["EWR", "HND"],
    ["HND", "ICN"],
    ["HND", "JFK"],
    ["ICN", "JFK"],
    ["JFK", "LGA"],
    ["EYW", "LHR"],
    ["LHR", "SFO"],
    ["SFO", "SAN"],
    ["SFO", "DSM"],
    ["SAN", "EYW"]
  ]
startingAirport = "LGA"
visited = {}
new_dict = {}
dict_routes = {}
for route in routes:
    if route[0] in dict_routes:
        dict_routes[route[0]].append(route[1])
    else:
        dict_routes[route[0]] = [route[1]]
        
for key, value in dict_routes.items():
    dict_value[key] = 1

def find_value(dict_routes, dict_value):
    for key, value in dict_routes.items():
        for route in value:
            if route in dict_routes:
                print(key, '--->', route, dict_routes[route])
                dict_value[key] += len(dict_routes[route])
                print(dict_value)
                del dict_routes[key]
            if route in dict_routes and key != dict_routes[route]:
                dict_value = find_value(dict_routes, dict_value) 
                
    return dict_value

dict_value = find_value(dict_routes, dict_value)            
print(dict_value)
# Out:
# DSM ---> ORD ['BGI']
# {'DSM': 2, 'ORD': 1, 'BGI': 1, 'SIN': 1, 'CDG': 1, 'DEL': 1, 'TLV': 1, 'EWR': 1, 'HND': 1, 'ICN': 1, 'JFK': 1, 'EYW': 1, 'LHR': 1, 'SFO': 1, 'SAN': 1}
# ORD ---> BGI ['LGA']
# {'DSM': 2, 'ORD': 2, 'BGI': 1, 'SIN': 1, 'CDG': 1, 'DEL': 1, 'TLV': 1, 'EWR': 1, 'HND': 1, 'ICN': 1, 'JFK': 1, 'EYW': 1, 'LHR': 1, 'SFO': 1, 'SAN': 1}
# SIN ---> CDG ['SIN', 'BUD']
# {'DSM': 2, 'ORD': 2, 'BGI': 1, 'SIN': 3, 'CDG': 1, 'DEL': 1, 'TLV': 1, 'EWR': 1, 'HND': 1, 'ICN': 1, 'JFK': 1, 'EYW': 1, 'LHR': 1, 'SFO': 1, 'SAN': 1}
# DEL ---> CDG ['SIN', 'BUD']
# {'DSM': 2, 'ORD': 2, 'BGI': 1, 'SIN': 3, 'CDG': 1, 'DEL': 3, 'TLV': 1, 'EWR': 1, 'HND': 1, 'ICN': 1, 'JFK': 1, 'EYW': 1, 'LHR': 1, 'SFO': 1, 'SAN': 1}
# EWR ---> HND ['ICN', 'JFK']
# {'DSM': 2, 'ORD': 2, 'BGI': 1, 'SIN': 3, 'CDG': 1, 'DEL': 3, 'TLV': 1, 'EWR': 3, 'HND': 1, 'ICN': 1, 'JFK': 1, 'EYW': 1, 'LHR': 1, 'SFO': 1, 'SAN': 1}
# HND ---> ICN ['JFK']
# {'DSM': 2, 'ORD': 2, 'BGI': 1, 'SIN': 3, 'CDG': 1, 'DEL': 3, 'TLV': 1, 'EWR': 3, 'HND': 2, 'ICN': 1, 'JFK': 1, 'EYW': 1, 'LHR': 1, 'SFO': 1, 'SAN': 1}
# ICN ---> JFK ['LGA']
# {'DSM': 2, 'ORD': 2, 'BGI': 1, 'SIN': 3, 'CDG': 1, 'DEL': 3, 'TLV': 1, 'EWR': 3, 'HND': 2, 'ICN': 2, 'JFK': 1, 'EYW': 1, 'LHR': 1, 'SFO': 1, 'SAN': 1}
# EYW ---> LHR ['SFO']
# {'DSM': 2, 'ORD': 2, 'BGI': 1, 'SIN': 3, 'CDG': 1, 'DEL': 3, 'TLV': 1, 'EWR': 3, 'HND': 2, 'ICN': 2, 'JFK': 1, 'EYW': 2, 'LHR': 1, 'SFO': 1, 'SAN': 1}
# LHR ---> SFO ['SAN', 'DSM']
# {'DSM': 2, 'ORD': 2, 'BGI': 1, 'SIN': 3, 'CDG': 1, 'DEL': 3, 'TLV': 1, 'EWR': 3, 'HND': 2, 'ICN': 2, 'JFK': 1, 'EYW': 2, 'LHR': 3, 'SFO': 1, 'SAN': 1}
# SFO ---> SAN ['EYW']
# {'DSM': 2, 'ORD': 2, 'BGI': 1, 'SIN': 3, 'CDG': 1, 'DEL': 3, 'TLV': 1, 'EWR': 3, 'HND': 2, 'ICN': 2, 'JFK': 1, 'EYW': 2, 'LHR': 3, 'SFO': 2, 'SAN': 1}
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-44-2b2d9e593104> in <module>
#      47     return dict_value
#      48
# ---> 49 dict_value = find_value(dict_routes, dict_value)
#      50 print(dict_value)
#      51
#
# <ipython-input-44-2b2d9e593104> in find_value(dict_routes, dict_value)
#      43                 del dict_routes[key]
#      44             if route in dict_routes and key != dict_routes[route]:
# ---> 45                 dict_value = find_value(dict_routes, dict_value)
#      46
#      47     return dict_value
#
# <ipython-input-44-2b2d9e593104> in find_value(dict_routes, dict_value)
#      43                 del dict_routes[key]
#      44             if route in dict_routes and key != dict_routes[route]:
# ---> 45                 dict_value = find_value(dict_routes, dict_value)
#      46
#      47     return dict_value
#
# <ipython-input-44-2b2d9e593104> in find_value(dict_routes, dict_value)
#      43                 del dict_routes[key]
#      44             if route in dict_routes and key != dict_routes[route]:
# ---> 45                 dict_value = find_value(dict_routes, dict_value)
#      46
#      47     return dict_value
#
# <ipython-input-44-2b2d9e593104> in find_value(dict_routes, dict_value)
#      43                 del dict_routes[key]
#      44             if route in dict_routes and key != dict_routes[route]:
# ---> 45                 dict_value = find_value(dict_routes, dict_value)
#      46
#      47     return dict_value
#
# <ipython-input-44-2b2d9e593104> in find_value(dict_routes, dict_value)
#      43                 del dict_routes[key]
#      44             if route in dict_routes and key != dict_routes[route]:
# ---> 45                 dict_value = find_value(dict_routes, dict_value)
#      46
#      47     return dict_value
#
# <ipython-input-44-2b2d9e593104> in find_value(dict_routes, dict_value)
#      43                 del dict_routes[key]
#      44             if route in dict_routes and key != dict_routes[route]:
# ---> 45                 dict_value = find_value(dict_routes, dict_value)
#      46
#      47     return dict_value
#
# <ipython-input-44-2b2d9e593104> in find_value(dict_routes, dict_value)
#      43                 del dict_routes[key]
#      44             if route in dict_routes and key != dict_routes[route]:
# ---> 45                 dict_value = find_value(dict_routes, dict_value)
#      46
#      47     return dict_value
#
# <ipython-input-44-2b2d9e593104> in find_value(dict_routes, dict_value)
#      43                 del dict_routes[key]
#      44             if route in dict_routes and key != dict_routes[route]:
# ---> 45                 dict_value = find_value(dict_routes, dict_value)
#      46
#      47     return dict_value
#
# <ipython-input-44-2b2d9e593104> in find_value(dict_routes, dict_value)
#      43                 del dict_routes[key]
#      44             if route in dict_routes and key != dict_routes[route]:
# ---> 45                 dict_value = find_value(dict_routes, dict_value)
#      46
#      47     return dict_value
#
# <ipython-input-44-2b2d9e593104> in find_value(dict_routes, dict_value)
#      35
#      36 def find_value(dict_routes, dict_value):
# ---> 37     for key, value in dict_routes.items():
#      38         for route in value:
#      39             if route in dict_routes:
#
# RuntimeError: dictionary changed size during iteration

# %%
def airportConnections(airports, routes, startingAirport):
    airportGraph = createAirportGraph(airports, routes)
    unreachableAirportNodes = getUnreachableAirportNodes(airportGraph, airports, startingAirport)
    return airportGraph

def createAirportGraph(airports, routes):
    airportGraph = {}
    for airport in airports:
        airportGraph[airport] = AirportNodes(airport)
    for route in routes:
        airport, connection = route
        airportGraph[airport].connections.append(connection)
    return airportGraph

def getUnreachableAirportNodes(airportGraph, airports, startingAirport):
    visitedAirports = {}
    depthFirstTraverseAirports(airportGraph, airport, visitedAirports)
    
    unreachableAirportNodes = []
    for airport in airports:
        if airport in visitedAirports:
            continue
        airportNode = airportGraph[airport]
        airportNode.reachable = False
        unreachableAirportNodes.append(airportNode)
    return unreachableAirportNodes

def depthFirstTraverseAirports(airportGraph, airport, visitedAirports):
    if airport in visitedAirports:
        return
    visitedAirports[airport] = True
    connections = airportGraph[airport].connections
    for connection in connections:
        depthFirstTraverseAirports(airportGraph, connection, visitedAirports):
        

class AirportNodes:
    def __init__(self, airport):
        self.airport = airport
        self.connections = []
        self.reachable = True
        self.unreachableConnections = []
    def __str__(self):
        return str(self.reachable)
    
airports = ["BGI", "CDG", "DEL", "DOH", "DSM", "EWR", "EYW", "HND", "ICN", "JFK", "LGA", "LHR", "ORD", "SAN", "SFO", "SIN", "TLV", "BUD"]
routes = [
    ["DSM", "ORD"],
    ["ORD", "BGI"],
    ["BGI", "LGA"],
    ["SIN", "CDG"],
    ["CDG", "SIN"],
    ["CDG", "BUD"],
    ["DEL", "DOH"],
    ["DEL", "CDG"],
    ["TLV", "DEL"],
    ["EWR", "HND"],
    ["HND", "ICN"],
    ["HND", "JFK"],
    ["ICN", "JFK"],
    ["JFK", "LGA"],
    ["EYW", "LHR"],
    ["LHR", "SFO"],
    ["SFO", "SAN"],
    ["SFO", "DSM"],
    ["SAN", "EYW"]
  ]
startingAirport = "LGA"

airportGraph = airportConnections(airports, routes, startingAirport)
print(airportGraph)
# Out:
# {'BGI': <__main__.AirportNodes object at 0x7fc3a83ce670>, 'CDG': <__main__.AirportNodes object at 0x7fc3a83c9550>, 'DEL': <__main__.AirportNodes object at 0x7fc3a83c96d0>, 'DOH': <__main__.AirportNodes object at 0x7fc3a83e0610>, 'DSM': <__main__.AirportNodes object at 0x7fc3a83e0b50>, 'EWR': <__main__.AirportNodes object at 0x7fc3a83e0880>, 'EYW': <__main__.AirportNodes object at 0x7fc3a83e0a30>, 'HND': <__main__.AirportNodes object at 0x7fc3a83e0700>, 'ICN': <__main__.AirportNodes object at 0x7fc3a83e0250>, 'JFK': <__main__.AirportNodes object at 0x7fc3a83e01f0>, 'LGA': <__main__.AirportNodes object at 0x7fc3a83e0190>, 'LHR': <__main__.AirportNodes object at 0x7fc3a83e0160>, 'ORD': <__main__.AirportNodes object at 0x7fc3a83e01c0>, 'SAN': <__main__.AirportNodes object at 0x7fc3a83e02e0>, 'SFO': <__main__.AirportNodes object at 0x7fc3a83e0310>, 'SIN': <__main__.AirportNodes object at 0x7fc3a83e03d0>, 'TLV': <__main__.AirportNodes object at 0x7fc3a83e0d30>, 'BUD': <__main__.AirportNodes object at 0x7fc3a83e0cd0>}
