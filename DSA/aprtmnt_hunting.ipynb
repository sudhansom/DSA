# %%
blocks = [
    {
      "gym": False,
      "school": True,
      "store": False
    },
    {
      "gym": True,
      "school": False,
      "store": False
    },
    {
      "gym": True,
      "school": True,
      "store": False
    },
    {
      "gym": False,
      "school": True,
      "store": False
    },
    {
      "gym": False,
      "school": True,
      "store": True
    }
  ]
reqs = ["gym", "school", "store"]
my_dict = {}
for i, item in enumerate(blocks):
    j = 0
    for key, value in item.items():
        if value:
            if i in my_dict:
                my_dict[i].append(1)
            else:
                my_dict[i] = [1]
        else:
            if i in my_dict:
                my_dict[i].append(0)
            else:
                my_dict[i] = [0]
        
    
print(my_dict)
# Out:
# {0: [0, 1, 0], 1: [1, 0, 0], 2: [1, 1, 0], 3: [0, 1, 0], 4: [0, 1, 1]}

# %%
blocks = [
    {
      "gym": False,
      "school": True,
      "store": False
    },
    {
      "gym": True,
      "school": False,
      "store": False
    },
    {
      "gym": True,
      "school": True,
      "store": False
    },
    {
      "gym": False,
      "school": True,
      "store": False
    },
    {
      "gym": False,
      "school": True,
      "store": True
    }
  ]
reqs = ["gym", "school", "store"]
dist = float('inf')
a = [float('inf') for _ in reqs]
for i, block in enumerate(blocks):
    for x, elem in enumerate(block):
        found_j = False
        found_k = False
        if block[elem]:
            a[x] = 0
            continue
        else:
            j = i
            k = i
            for j in range(i-1, -1, -1):
                if blocks[j][elem]:
                    found_j = True
                    break
            for k in range(i + 1, len(blocks)):
                if blocks[k][elem]:
                    found_k = True
                    break
        if i - j and k - i and found_j and found_k:
            a[x] = min(i-j, k - i)
        elif i - j and found_j:
            a[x] = i - j
        elif k - i and found_k:
            a[x] = k - i
#         print(i, i - j, k - i)
        if max(a) < dist:
            dist  = max(a)
            m = i
    
    
print(dist, m)
# Out:
# 1 3

# %%
blocks = [
    {
      "gym": False,
      "school": True,
      "store": False
    },
    {
      "gym": True,
      "school": False,
      "store": False
    },
    {
      "gym": True,
      "school": True,
      "store": False
    },
    {
      "gym": False,
      "school": True,
      "store": False
    },
    {
      "gym": False,
      "school": True,
      "store": True
    }
  ]
reqs =["gym", "school", "store"]
req = [['x' for _ in blocks] for _ in reqs]
indx = 9
for k, elem in enumerate(reqs):
    for i, block in enumerate(blocks):
        if block[elem]:
            indx = i
            req[k][i] = 0
        else:
            req[k][i] = abs(i - indx)
    for i, block in enumerate(reversed(blocks)):
        if block[elem]:
            req[k][len(blocks)-1-i] = 0
            indx = i
        else:
            req[k][len(blocks)-i-1] = min(req[k][len(blocks)-i-1], abs(indx - i))

result = [0 for _ in blocks]
for i in range(len(blocks)):
    a = 0
    for item in req:
        if item[i] > a:
            a = item[i]
    result[i] = a
min_indx = float('inf')               
for i, elem in enumerate(result[1:]):
    if elem < result[i - 1]:
        min_indx = i - 1
    else:
        min_indx = i
        
print(min_indx)
# Out:
# 3

# %%
blocks = [
    {
      "gym": False,
      "office": True,
      "school": True,
      "store": False
    },
    {
      "gym": True,
      "office": False,
      "school": False,
      "store": False
    },
    {
      "gym": True,
      "office": False,
      "school": True,
      "store": False
    },
    {
      "gym": False,
      "office": False,
      "school": True,
      "store": False
    },
    {
      "gym": False,
      "office": False,
      "school": True,
      "store": False
    },
    {
      "gym": False,
      "office": False,
      "school": True,
      "store": True
    }
  ]
reqs = ["gym", "office", "school", "store"]
req = [['x' for _ in blocks] for _ in reqs]
indx = 9
for k, elem in enumerate(reqs):
    for i, block in enumerate(blocks):
        if block[elem]:
            indx = i
            req[k][i] = 0
        else:
            req[k][i] = abs(i - indx)
    for i, block in enumerate(reversed(blocks)):
        if block[elem]:
            req[k][len(blocks)-1-i] = 0
            indx = i
        else:
            req[k][len(blocks)-i-1] = min(req[k][len(blocks)-i-1], abs(indx - i))

print(req)
result = [0 for _ in blocks]
for i in range(len(blocks)):
    a = 0
    for item in req:
        if item[i] > a:
            a = item[i]
    result[i] = a
print(result)
min_indx = float('inf')               
for i, elem in enumerate(result[1:]):
    if elem < result[i - 1]:
        min_indx = i - 1
    else:
        min_indx = i
        
print(min_indx)
# Out:
# [[1, 0, 0, 0, 1, 2], [0, 1, 2, 2, 1, 0], [0, 1, 0, 0, 0, 0], [5, 4, 3, 2, 1, 0]]
# [5, 4, 3, 2, 1, 2]
# 4

# %%
blocks = [
    {
      "gym": False,
      "school": True,
      "store": False
    },
    {
      "gym": True,
      "school": False,
      "store": False
    },
    {
      "gym": True,
      "school": True,
      "store": False
    },
    {
      "gym": False,
      "school": True,
      "store": False
    },
    {
      "gym": False,
      "school": True,
      "store": True
    }
  ]
reqs = ["gym", "school", "store"]
dist = []
value = float('inf')
indx = 0
max_value = float('-inf')
for i, block in enumerate(blocks):
    max_value = float('-inf')
    for elem in block:
        min_value = float('inf')
        for j in range(len(blocks)):
            if blocks[j][elem]:
                min_value = min(min_value, abs(i - j))
        max_value = max(max_value, min_value)
    if max_value < value:
        value = max_value
        indx = i
#     if len(dist):
#         if max_value < dist[-1]:
#             indx = len(dist)
#     dist.append(max_value)
#     max_value = max(min_value, max_value)
    print(max_value)

    
    
print(dist, indx)
# Out:
# 4
# 3
# 2
# 1
# 2
# [] 3
